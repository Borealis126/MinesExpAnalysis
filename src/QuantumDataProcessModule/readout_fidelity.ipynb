# %%
import qdpm
import numpy as np
import matplotlib.pyplot as plt

# %%
rd_fid = qdpm.Experiment(r"O:\68707\BF2222\LABVIEWdata\Cooldown20200119_Nb_SWIPHT_MB_W8_180nm\heterodyne\QST\YPiO2 X Id\2020_01_28_17_55_40")

# %%
clf = qdpm.SingleQubitClassifier(rd_fid, qubit=0)
prediction = clf.predict()
population = 1 - prediction.mean(axis=1)

# %%
clf.plot_boundary()

# %%
clf = qdpm.SingleQubitClassifier(rd_fid, qubit=1)
prediction = clf.predict()
population = 1 - prediction.mean(axis=1)

# %%
clf.plot_boundary()
