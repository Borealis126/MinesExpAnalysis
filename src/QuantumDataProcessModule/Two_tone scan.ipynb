# %%
import qdpm
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# %%
exp = qdpm.Experiment(r'O:\68707\BFXLD2222\LabVIEWData\Cooldown20211015\Heterodyne\Two-tone\2021_11_16_13_55_50')

# %%
# norm = np.zeros(exp.mean_mag()[0].T.shape)
# for i in range(exp.mean_mag()[0].T.shape[0]):
#     norm[i, :] = exp.mean_mag()[0].T[i, :]-(exp.scan_value[1][i]+15)

# %%
fig, ax = plt.subplots()
img = ax.pcolormesh(exp.mean_phase()[0].T, cmap='jet')

ax.set_xticks(np.arange(0, exp.scan_size[0], 50))
ax.set_xticklabels(np.round(exp.scan_value[0][0::50], decimals=6))
ax.set_yticks(np.arange(0, exp.scan_size[1], 10))
ax.set_yticklabels(np.round(exp.scan_value[1][0::10], decimals=4))

# ax.set_xlabel('Frequency (GHz)', fontsize=14)
# ax.set_ylabel('Power (dBm)', fontsize=14)
# ax.set_title('Power Scan S21', fontsize=14)
cb = fig.colorbar(img)
plt.show()

# %%
plt.plot(np.sqrt(exp.data[0][1][:, -1, -1]**2+exp.data[0][0][:, -1, -1]**2))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-0f46a3fe1071> in <module>
# ----> 1 plt.plot(np.sqrt(exp.data[0][1][:, -1, -1]**2+exp.data[0][0][:, -1, -1]**2))
#
# IndexError: too many indices for array

# %%
plt.plot(np.sqrt(exp.data[0][1][:, -1, -2]**2+exp.data[0][0][:, -1, -2]**2))

# %%
plt.plot(exp.mean_mag()[0][:, -1])

# %%
plt.plot(np.sqrt(exp.average()[0][0][:, -1]**2+exp.average()[0][1][:, -1]**2))

# %%
exp.scan_init
# Out:
#                                 0
# Readout freq (GHz)        6.14472
# Readout pwr (dBm)        15.00000
# Readout atten (dB)      -40.00000
# Qubit freq (GHz)          5.97520
# Qubit pwr (dBm)          10.00000
# Qubit atten (dB)          0.00000
# Qubit bias (mA/mV)      124.60000
# Amplifier freq (GHz)      6.08496
# Amplifier pwr (dBm)       1.31000
# Amplifier atten (dB)      0.00000
# Amplifier bias (mA/mV)    0.00000
